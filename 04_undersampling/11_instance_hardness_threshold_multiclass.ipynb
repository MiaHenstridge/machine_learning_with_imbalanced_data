# %% [markdown]
# # Instance Hardness Threshold
# Machine Learning with Imbalanced Data - Course
#
# Instance hardness is the probability of an observation being miss-classified. In other words, the instance hardness is 1 minus the probability of the class. For class 1:
#
# * instance hardness = 1 - p(1)
#
# The instance hardness depends on the algorithm used in the classification and in class separability.

# %% [markdown]
# ## Instance Hardness Filtering
# Instance Hardness filtering consists in determining the instance hardness and removing the observations that are harder to classify. That is, removing the observations with high instance hardness or low class probability. The question is, how to determine the threshold.
#
# In this notebook we will:
#
# * Determine the instance hardness of observations
# * Filter observations from the majority class based of an arbitrary threshold
# * Filter observations from the majority class as proposed by Imbalanced-learn
# * Use imbalance-learn to implement Instance Hardness
#
# In this notebook we will use an example of multiclass classification.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_predict
from sklearn.multiclass import OneVsRestClassifier

from imblearn.under_sampling import InstanceHardnessThreshold

# %% [markdown]
# ## Function to create data
# We create a function to create data with 2 or more classes, with different class separability and imbalance ratio. The user can determine how many classes to create and how separate they are. The data will contain 2 predictive variables and 1 target with the classes.

# %%
def make_data(n_classes, weights, sep):
    # returns arrays
    X, y = make_classification(n_samples=1000,
                               n_features=2,
                               n_classes=n_classes,
                               n_redundant=0,
                               n_clusters_per_class=1,
                               weights=weights,
                               class_sep=sep,
                               random_state=1)
    
    # transform arrays into pandas df and series
    X = pd.DataFrame(X, columns=['varA', 'varB'])
    y = pd.Series(y)

    return X, y

# %% [markdown]
# ## Create and plot a toy binary dataset

# %%
# binary classification -> 2 classes
X, y = make_data(n_classes=3,   # multiclass
                 weights=[0.5, 0.4, 0.1],    # imbalance 10:1
                 sep=0.5,   # class separability
                 )

# print the target imbalance
print('Target imbalance: ')
print(y.value_counts())

# plot the data
sns.scatterplot(
    data=X, x='varA', y='varB', hue=y
)

plt.title('Multiclass classification')
plt.show()
# Out:
# Target imbalance:
# 0    496
# 1    399
# 2    105
# Name: count, dtype: int64

# %% [markdown]
# The minority class in dark purple, and the majority classes are in lighter pinks. There is some class overlap.

# %% [markdown]
# ## Train Random Forests
# We will use Random Forests to determine instance hardness. We will do so with cross-validation to try and perform the procedure as closely as possible to the imbalanced-learn implementation. To determine the instance hardness, we will do so in a one vs. rest manner. So we wrap the algorithm with a `OneVsRestClassifier`.

# %%
# set up a stratified cross-validation scheme
skf = StratifiedKFold(
    n_splits=3,
    shuffle=True,
    random_state=1
)

skf
# Out:
# StratifiedKFold(n_splits=3, random_state=1, shuffle=True)

# %%
# set up the random forest
# in a 1 vs. rest manner
rf = OneVsRestClassifier(
    RandomForestClassifier(n_estimators=10, random_state=1, max_depth=2),
    n_jobs=-1
)

# %% [markdown]
# ## Calculate instance hardness values

# %%
# obtain the predictions from the random forests
# with cross validation
probs = cross_val_predict(
    rf,
    X,
    y,
    cv=skf,
    n_jobs=-1,
    method='predict_proba',
)

probs = pd.DataFrame(probs, columns=['p(0)', 'p(1)', 'p(2)'])

# the probabiities are 1 vs Rest
probs
# Out:
#          p(0)      p(1)      p(2)
# 0    0.690328  0.256658  0.053014
# 1    0.241402  0.328094  0.430504
# 2    0.429384  0.497497  0.073119
# 3    0.663519  0.273183  0.063298
# 4    0.202036  0.453133  0.344831
# ..        ...       ...       ...
# 995  0.656766  0.270403  0.072832
# 996  0.666431  0.280055  0.053514
# 997  0.642936  0.292809  0.064254
# 998  0.312638  0.569629  0.117733
# 999  0.461141  0.349465  0.189394
#
# [1000 rows x 3 columns]

# %% [markdown]
# The classes 0 and 1 are the majority classes. So we want to undersample those. We can do so by removing observations with low p(0) and p(1), which is the same as saying high instance hardness. Remember that instance hardness is 1 - prob.

# %% [markdown]
# ## Undersample observations from the majority class

# %% [markdown]
# ### Arbitrary method

# %%
# to pick a threshold, let's examine the probability distribution
probs.describe()
# Out:
#               p(0)         p(1)         p(2)
# count  1000.000000  1000.000000  1000.000000
# mean      0.491178     0.403093     0.105729
# std       0.205294     0.167309     0.099443
# min       0.060039     0.148687     0.041796
# 25%       0.276382     0.269223     0.055158
# 50%       0.605652     0.318781     0.066503
# 75%       0.675442     0.551213     0.105131
# max       0.730871     0.782360     0.655570

# %% [markdown]
# We see that most observations of the majority class show p(0) >~ 0.30. We can try and remove observations under this value. This is arbitrary of course, we would have to try several thresholds and see what works best for our data.

# %%
# the 2 expressions are equivalent:
# remove obs. from majorty class where instance hardness ( 1 - p(0) ) is high
# remove obs. from majorty class where p(0) is low

# we remove observations from the majority (only) where the 
# random forests return probabilities below 0.30

condition_0 = (y==0) & (probs['p(0)'] <= 0.30)
condition_1 = (y==1) & (probs['p(1)'] <= 0.30)

# find those observations in the dataset
filtered_0 = X.loc[condition_0]
filtered_1 = X.loc[condition_1]

# number of observations to remove
filtered_0.shape, filtered_1.shape
# Out:
# ((18, 2), (69, 2))

# %%
# let's identify which observations will be removed
# first from class 0
# plot the data
sns.scatterplot(
    data=X, x='varA', y='varB', hue=y+3*condition_0
)

plt.title('Binary classification')
plt.show()

# %% [markdown]
# The darkest color (label 3) are those that will be removed. See how they are at the border of class 2 - the minority class.

# %%
# let's identify which observations will be removed
# from class 1
# plot the data
sns.scatterplot(
    data=X, x='varA', y='varB', hue=y+3*condition_1
)

plt.title('Binary classification')
plt.show()

# %% [markdown]
# The darkest color (label 4) are those that will be removed. See how they are at the border of class 0, the other majority class

# %%
# drop hard instances from both majority classes

# remove class 0 - hard instances
X_resampled = X.drop(filtered_0.index)
y_resampled = y.drop(filtered_0.index)

# remove class 1 - hard instances
X_resampled = X_resampled.drop(filtered_1.index)
y_resampled = y_resampled.drop(filtered_1.index)

# %%
X_resampled.shape, y_resampled.shape
# Out:
# ((913, 2), (913,))

# %%
# print the target imabalance after filtering

print('Resampled Target imbalance: ')
print(y_resampled.value_counts())
# Out:
# Resampled Target imbalance:
# 0    478
# 1    330
# 2    105
# Name: count, dtype: int64

# %%
# plot resampled data

sns.scatterplot(
        data=X_resampled, x="varA", y="varB", hue=y_resampled
    )

plt.title('Resampled dataset')
plt.show()

# %% [markdown]
# ### Under sample data to match balancing ratio
# In the following section, instead of using an arbitrary method, we will find a threshold that equilibrates the balancing ratio.
#
# We need to do this procedure for each of the majority classes.

# %%
# the target imbalance
balance = y.value_counts()

balance
# Out:
# 0    496
# 1    399
# 2    105
# Name: count, dtype: int64

# %%
class_ = 0

# number of samples needed
n_samples = balance[2]

# total obs from majority
majority_samples = balance[class_]

# in which percentile do we find these number of observations
perc = n_samples / majority_samples

perc
# Out:
# 0.21169354838709678

# %%
# we want the observations with the highest p(0)
# so we are looking at the top perc
perc = (1-perc)*100

perc
# Out:
# 78.83064516129032

# %%
# find the threshold at which we find 78% of the observations

threshold_0 = np.percentile(probs[y == class_]['p(0)'], perc)

threshold_0
# Out:
# 0.693734670570368

# %%
# to make this a bit more visual

probs[y == class_]['p(0)'].hist(cumulative=True, bins=100)
plt.axvline(x=threshold_0, color='red')

# %%
# remove observations from the majority only where the random forests 
# return probs below threshold
condition_0 = (y==class_) & (probs['p(0)'] < threshold_0)

# find those observations in the dataset
filtered_0 = X.loc[condition_0]

# number of observations to remove
filtered_0.shape
# Out:
# (385, 2)

# %%
# identify which observations to be removed
# plot the data
sns.scatterplot(
    data=X, x='varA', y='varB', hue=y+3*condition_0
)

plt.title('Multiclass classification')
plt.show()

# %%
# repeat the procedure for class 1
class_ = 1

# number of samples needed
n_samples = balance[2]

# total obs from majority
majority_samples = balance[class_]

# in which percentile do we find these number of observations
perc = n_samples / majority_samples

perc
# Out:
# 0.2631578947368421

# %%
# we want the observations with the highest p(0)
# so we are looking at the top perc
perc = (1-perc)*100

perc
# Out:
# 73.6842105263158

# %%
# find the threshold at which we find 78% of the observations

threshold_1 = np.percentile(probs[y == class_]['p(1)'], perc)

threshold_1
# Out:
# 0.6581840116263563

# %%
# to make this a bit more visual

probs[y == class_]['p(1)'].hist(cumulative=True, bins=100)
plt.axvline(x=threshold_1, color='red')

# %%
# remove observations from the majority only where the random forests 
# return probs below threshold
condition_1 = (y==class_) & (probs['p(1)'] < threshold_1)

# find those observations in the dataset
filtered_1 = X.loc[condition_1]

# number of observations to remove
filtered_1.shape
# Out:
# (291, 2)

# %%
# identify which observations to be removed
# plot the data
sns.scatterplot(
    data=X, x='varA', y='varB', hue=y+3*condition_1
)

plt.title('Multiclass classification')
plt.show()

# %%
# drop hard instances

X_resampled = X.drop(filtered_0.index)
y_resampled = y.drop(filtered_0.index)

X_resampled = X_resampled.drop(filtered_1.index)
y_resampled = y_resampled.drop(filtered_1.index)

X_resampled.shape, y_resampled.shape
# Out:
# ((324, 2), (324,))

# %%
# print the target imabalance after filtering

print('Resampled Target imbalance: ')
print(y_resampled.value_counts())
# Out:
# Resampled Target imbalance:
# 0    111
# 1    108
# 2    105
# Name: count, dtype: int64

# %% [markdown]
# As we can see, we did reduce the number of observations from the majority, but we did not achieve the desired balance, because there are many observations that have a similar probability value. So this algorithm retains them all.

# %%
# finally plot resampled data

sns.scatterplot(
        data=X_resampled, x="varA", y="varB", hue=y_resampled
    )

plt.title('Resampled dataset')
plt.show()

# %% [markdown]
# ### Instance hardness with imbalanced-learn

# %%
# set up instance hardness threshold
iht = InstanceHardnessThreshold(
    estimator=rf,
    sampling_strategy='auto',
    random_state=1,
    n_jobs=-1,
    cv=3,
)

X_resampled, y_resampled = iht.fit_resample(X, y)

# %%
# original data
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
# undersampled data
X_resampled.shape, y_resampled.shape
# Out:
# ((323, 2), (323,))

# %%
# balance ratio after resampling
y_resampled.value_counts()
# Out:
# 0    109
# 1    109
# 2    105
# Name: count, dtype: int64

# %%
# plot original data
sns.scatterplot(
    data=X, x='varA', y='varB', hue=y
)

plt.title('Original dataset')
plt.show()

# %%
# plot undersampled data
sns.scatterplot(
    data=X_resampled, x='varA', y='varB', hue=y_resampled
)

plt.title('Undersampled dataset')
plt.show()
